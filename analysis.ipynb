# %%
import pandas as pd

data = pd.read_csv("data/MOTION/data.dat", sep=' ')
for idx, col in enumerate(data.columns):
    print(f'{idx}, {col}')

for value in [0, 1, 2, 120, 121, 122]:
    print(data.iloc[:,value].dtypes)

print(data.shape)
# Out:
# 0, Unnamed: 0.1
# 1, Unnamed: 0
# 2, attitude.roll
# 3, attitude.pitch
# 4, attitude.yaw
# 5, gravity.x
# 6, gravity.y
# 7, gravity.z
# 8, rotationRate.x
# 9, rotationRate.y
# 10, rotationRate.z
# 11, userAcceleration.x
# 12, userAcceleration.y
# 13, userAcceleration.z
# int64
# int64
# float64
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 8
#       5     print(f'{idx}, {col}')
#       7 for value in [0, 1, 2, 120, 121, 122]:
# ----> 8     print(data.iloc[:,value].dtypes)
#      10 print(data.shape)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexing.py:1184, in _LocationIndexer.__getitem__(self, key)
#    1182     if self._is_scalar_access(key):
#    1183         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
# ...

# %% [markdown]
# ## Análises da tarefa de pretexto

# %% [markdown]
# #### Melhor backbone ACC

# %%
from utils.functions import loadCheckPointData
from data.datas import Datas

dataMain = Datas.MOBIT.value
ck = loadCheckPointData(path="best_models/", file_name=f"backbone_{dataMain}", device="cpu")
print("Best Acuracy: ",ck['accuracy'])
# Out:
# Best Acuracy:  79.06574394463668

# %% [markdown]
# #### Train Error

# %%
from utils.plots import plot_curves
import pandas as pd

df = pd.read_csv(f'results_data/backbone_{dataMain}_train.dat', sep=" ")
plot_curves(data1=df["train"], data2=df["validation"], data1_legend="Train", data2_legend="Validation", title="Train x Validation")

# %% [markdown]
# ### Análises da tarefa de downstream

# %% [markdown]
# #### Melhor ACC

# %%
from utils.functions import loadCheckPointData

ck = loadCheckPointData(path="best_models/", file_name="downstream", device="cpu")
print("Best Acuracy: ",ck['accuracy'])
# Out:
# Best Acuracy:  66.66666666666667

# %% [markdown]
# #### Train Error

# %%
from utils.plots import plot_curves
import pandas as pd

df = pd.read_csv('results_data/downstream_train.dat', sep=" ")
plot_curves(data1=df["train"], data2=df["validation"], data1_legend="Train", data2_legend="Validation", title="Train x Validation")
